# %% [markdown]
# <a href="https://colab.research.google.com/github/Basicsj/dataAnalysis/blob/main/_%EC%B0%B8%EB%B9%9B03_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%BD%94%EB%94%A9%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #파이썬 문법(Python Syntax)

# %% [markdown]
# ## 조건문 (condition) -  if , if~ else
#
# * 특정한 조건에 따라 실행해야 하는 과정이 달라야 할
# 때 사용한다
# * 파이썬에서는 조건절을 표현할 때 괄호를 사용하지 않는다
# * 조건절이 끝나면 반드시 콜론 을 써야 한다
# * 조건절 후, 그 다음 문장을 쓸 때 들여쓰기를 해야 한다
# * 자동으로 들여쓰기 된다

# %% [markdown]
# ![조건문.png](data:image/png;base64,...)

# %%
a = 20
b = 50

# %%
if ( a > b) :
    print("큰 수는 =", a)
else:
    print("큰 수는 =", b)
# Out:
# 큰 수는 = 50

# %%
if a > b:

# %% [markdown]
# *  만약에
# ** a버튼이 눌렸으면 smile
# ** b버튼이 눌렸으면 angry
#
# ```
# if( 버튼 == 'a'):
#     print("smile")
# if(버튼 == 'b'):
#     print('angry')
# ```

# %%
버튼 = input("어떤 버튼을 누를 거야? ")
# Out:
# 어떤 버튼을 누를 거야? a

# %%
if( 버튼 == 'a'):
    print("smile")
if(버튼 == 'b'):
    print('angry')
# Out:
# smile

# %% [markdown]
# ### 홀수 짝수 판별하기  if~
# ![image.png](data:image/png;base64,...)
# *

# %%
a = int(input("입력값은 : "))
# Out:
# 입력값은 : 4

# %%
if ( a % 2 == 0):
    print(" 짝수입니다")
else:
    print("홀수입니다")
# Out:
#  짝수입니다

# %% [markdown]
# ### if ~  elif
# * 조건이 두개 이상의 그룹으로 나눌 수 있는 경우에 사용한다
# * 조건이 구간으로 나누어지는 경우
# ** 성적분포 ,나이에 따른 요금 계산 등
# * 연속되는 조건문을 사용한다
# * elif 는 “else 의 축약어
# * elif 문을 몇 번이고 사용할 수 있다
# * 마지막 분기에서는 else 문으로 이루어진다
#
#
# ![image.png](data:image/png;base64,...)
# ```
# x = 5
# y = 10
# if x < y :
#     print(x, "는", y ,"보다 작습니다")
# elif x > y :
#     print(x, "는", y, "보다 큽니다")
# else :
#     print(x, "와", y, "는 같습니다")
# ```

# %%
x = 5
y = 10
if x < y :
    print(x, "는", y ,"보다 작습니다")
elif x > y :
    print(x, "는", y, "보다 큽니다")
else :
    print(x, "와", y, "는 같습니다")
# Out:
# 5 는 10 보다 작습니다

# %% [markdown]
# ### 나이에 따른 입장료 계산하기
# ![image.png](data:image/png;base64,...)

# %%
charge  = 5000

# %%
age = int(input("나이는 ? "))
if(age <8):
    print("charge: free " )
elif(age < 60):
    print("charge: ", charge)
else:
    print("charge: ", charge*0.5)
# Out:
# 나이는 ? 4
# charge: free

# %% [markdown]
# ## 관계연산자
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 관계연산자 실습하기

# %% [markdown]
# ### 0 < x < 100 표현방법
#
# ```
# if x > 0 and x < 100 :
#
# If 0 < x < 100:
# ```

# %%
x = 70
0 < x < 100
# Out:
# True

# %% [markdown]
# ### x < 0 또는 x > 100 표현방법
#
# ```
# if x < 0 or x > 100 :
#
# ```

# %% [markdown]
# ## 논리 연산자
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###관계 논리연산자 실습하기

# %%
a = int(input("나이는 ?  "))

if( a>= 8 and a<60):
    print("유료")
else:
    print("무료")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 아트란티스 탑승제한 코딩하기
# 키는 135cm 미만 / 190cm 초과 / 나이65세 이상
#
#
#
# ```
# height = int(input("탑승자의 키는 ?  "))
# age = int(input("나이는 ?  "))
#
# if 135 <= height <= 190 and age <= 65 :
#     print("탑승이 가능합니다, 즐거운 시간되세요")
# else :
#     print("탑승이 제한되었습니다")
# ```

# %%
height = int(input("탑승자의 키는 ?  "))
age = int(input("나이는 ?  "))

if 135 <= height <= 190 and age <= 65 :
    print("탑승이 가능합니다, 즐거운 시간되세요")
else :
    print("탑승이 제한되었습니다")
# Out:
# 탑승자의 키는 ?  150
# 나이는 ?  10
# 탑승이 가능합니다, 즐거운 시간되세요

# %% [markdown]
# ### BMI 지수를 기준으로 현재 건강상태 안내하기
#
# * 키의 변수명: height
# * 몸무게의 변수명: weight
# * 조건문 중에 if ~ elif 문 사용
# * float() : 소숫점이 있는 실수를 입력받을 때 변환하는 함수 ← 비교 int()
#
# ** 힌트
#
#
# ```
# height = float(input("키를 m 단위로 입력해 주세요 ; "))
# weight = float(input("몸무게를 kg 단위로 입력해 주세요 ; "))
# bmi= weight / (height *height)
# if bmi < 18.5 :
#     print("BMI지수는 ", bmi ," 이며  저체중 상태입니다")
# elif bmi < 23 #  계속해서 코드를 작성해 보세요
#
# ```

# %%
height = float(input("키를 m 단위로 입력해 주세요 ; "))
weight = float(input("몸무게를 kg 단위로 입력해 주세요 ; "))
bmi= weight / (height *height)
if bmi < 18.5 :
    print("BMI지수는 ", bmi ," 이며  저체중 상태입니다")
elif bmi < 23 #  계속해서 코드를 작성해 보세요
# Out:
# 키를 m 단위로 입력해 주세요 ; 160
# 몸무게를 kg 단위로 입력해 주세요 ; 50
# BMI지수는  0.001953125  이며  저체중 상태입니다
